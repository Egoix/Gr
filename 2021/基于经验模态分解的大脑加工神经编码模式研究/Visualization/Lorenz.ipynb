# %% [markdown]
# 绘制洛伦兹吸引子 示例图

# %%
from scipy.integrate import odeint 
import numpy as np

# %%
def lorenz(w, t, p, r, b): 
    # 给出位置矢量w，和三个参数p, r, b计算出
    # dx/dt, dy/dt, dz/dt的值
    x, y, z = w
    # 直接与lorenz的计算公式对应 
    return np.array([p*(y-x), x*(r-z)-y, x*y-b*z]) 

t = np.arange(0, 30, 0.01) # 创建时间点 
# 调用ode对lorenz进行求解, 用两个不同的初始值 
track1 = odeint(lorenz, (0.0, 1.00, 0.0), t, args=(10.0, 28.0, 3.0)) 
track2 = odeint(lorenz, (0.0, 1.01, 1.0), t, args=(10.0, 28.0, 3.0))

# %%
# 绘图
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.plot(track1[:,0], track1[:,1], track1[:,2],"#00FA9A")
ax.plot(track2[:,0], track2[:,1], track2[:,2],"#FF8C00")
plt.savefig("lorenz.png", dpi=300, bbox_inches = 'tight')
plt.show()
# Out:
# D:\software\anaconda\envs\python37\lib\site-packages\ipykernel_launcher.py:2: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
