# %%
import mne
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
import matplotlib as mpl


#加载数据
for i in range(1,16):
    for j in range(1,4):
        data = scipy.io.loadmat(f'D:\数据集\SEED\Preprocessed_EEG//{i}_{j}.mat')
         #print(data)

         #创建info 包括通道名称和类型 采样频率=200Hz
        info = mne.create_info(
        ch_names=['FP1','FPZ','FP2','AF3','AF4','F7','F5','F3','F1','FZ','F2','F4','F6'
            ,'F8','FT7','FC5','FC3','FC1','FCZ','FC2','FC4','FC6','FT8','T7','C5'
            ,'C3','C1','CZ','C2','C4','C6','T8','TP7','CP5','CP3','CP1','CPZ','CP2'
            ,'CP4','CP6','TP8','P7','P5','P3','P1','PZ','P2','P4','P6','P8','PO7'
            ,'PO5','PO3','POZ','PO4','PO6','PO8','CB1','O1','OZ','O2','CB2'],
        ch_types=['eeg' for _ in range(62)],
        sfreq=200    
        )
        #创建raw
        c = 0
        raw = []                   
        if i == 1:
            for k in range(1,16):
                data_key = f"djc_eeg{k}" 
                #print(data_key)
                tmp_data = data[data_key]
                #print(type(tmp_data))
                #shape=shape_max
                c = max(c, tmp_data.shape[1])
                raw.append(tmp_data)


        if i == 2 :  
          
            for k in range(1,16):
                data_key = f"jl_eeg{k}" 
                tmp_data = data[data_key]
                c = max(c, tmp_data.shape[1])
                raw.append(tmp_data)
                
        if i == 3 :  
          
            for k in range(1,16):
                data_key = f"jj_eeg{k}" 
                tmp_data = data[data_key]
                c = max(c, tmp_data.shape[1])
                raw.append(tmp_data)

        if i == 4:  
           
            for k in range(1,16):
                data_key = f"lqj_eeg{k}" 
                tmp_data = data[data_key]
                c = max(c, tmp_data.shape[1])
                raw.append(tmp_data)

        if i == 5 :  
            
            for k in range(1,16):
                data_key = f"ly_eeg{k}" 
                tmp_data = data[data_key]
                c = max(c, tmp_data.shape[1])
                raw.append(tmp_data)

        if i == 6 :  
          
            for k in range(1,16):
                data_key = f"mhw_eeg{k}" 
                tmp_data = data[data_key]
                c = max(c, tmp_data.shape[1])
                raw.append(tmp_data)

            
        if i == 7 :  
        
            for k in range(1,16):
                data_key = f"phl_eeg{k}" 
                tmp_data = data[data_key] 
                c = max(c, tmp_data.shape[1])
                raw.append(tmp_data)

                
        if i == 8 :  
           
            for k in range(1,16):
                data_key = f"sxy_eeg{k}" 
                tmp_data = data[data_key] 
                c = max(c, tmp_data.shape[1])
                raw.append(tmp_data)

                
        if i == 9 :  
         
            for k in range(1,16):
                data_key = f"wk_eeg{k}"
                tmp_data = data[data_key] 
                c = max(c, tmp_data.shape[1])
                raw.append(tmp_data)
               
                
        if i == 10 :  
         
            for k in range(1,16):
                data_key = f"ww_eeg{k}" 
                tmp_data = data[data_key]
                c = max(c, tmp_data.shape[1])
                raw.append(tmp_data)

        if i == 11 : 
        
            for k in range(1,16):
                data_key = f"wsf_eeg{k}" 
                tmp_data = data[data_key]
                c = max(c, tmp_data.shape[1])
                raw.append(tmp_data)

                
        if i == 12 : 
            
            for k in range(1,16):
                data_key = f"wyw_eeg{k}" 
                tmp_data = data[data_key]
                c = max(c, tmp_data.shape[1])
                raw.append(tmp_data)

               
        if i == 13 :  
          
            for k in range(1,16):
                data_key = f"xyl_eeg{k}" 
                tmp_data = data[data_key]
                c = max(c, tmp_data.shape[1])
                raw.append(tmp_data)

               
        if i == 14 :  
          
            for k in range(1,16):
                data_key = f"ys_eeg{k}" 
                tmp_data = data[data_key]
                c = max(c, tmp_data.shape[1])
                raw.append(tmp_data)

        if i == 15 :  
            for k in range(1,16):
                data_key = f"zjy_eeg{k}" 
                tmp_data = data[data_key]
                c = max(c, tmp_data.shape[1])
                raw.append(tmp_data)

        a = len(raw)
        b,_ = raw[0].shape
        tmp = np.zeros((a,b,c))
        for x in range(a):
            for y in range(b):
                tmp_l = len(raw[x][y,:])
                tmp[x,y ,:tmp_l] = raw[x][y,:]
        raw = tmp
    
        #创建events
        
        events = np.array([
                [0, 0, 3],
                [1, 0, 2],
                [2, 0, 1],
                [3, 0, 1],
                [4, 0, 2],
                [5, 0, 3],
                [6, 0, 1],
                [7, 0, 2],
                [8, 0, 3],
                [9, 0, 3],
                [10, 0, 2],
                [11, 0, 1],
                [12, 0, 2],
                [13, 0, 3],
                [14, 0, 1],
        ])
        
        # 创建event id，受试者观看的电影情感类型
        event_id = dict(negative=1, neutral=2,positive=3)
        # tmin, tmax = -0.2, 0.5
        
        #创建epochs对象
        epochs = mne.EpochsArray(raw,info=info, events=events, event_id=event_id)
        #print(epochs)
        #print(epochs.events[:3])
        #epochs['positive'].average().plot(time_unit='s')
        #epochs.plot(block=True)
        #plt.show()
        #epochs.plot(scalings=dict(eeg=1e-200))
        #save epochs
        #epochs.save(f"{i}_{j}-epo.fif", overwrite=True)
epochs.set_montage('standard_1020')
# Out:
# Not setting metadata
# Not setting metadata
# 15 matching events found
# No baseline correction applied
# 0 projection items activated
# 0 bad epochs dropped
# Not setting metadata
# Not setting metadata
# 15 matching events found
# No baseline correction applied
# 0 projection items activated
# 0 bad epochs dropped
# Not setting metadata
# Not setting metadata
# 15 matching events found
# No baseline correction applied
# 0 projection items activated
# 0 bad epochs dropped
# Not setting metadata
# Not setting metadata
# 15 matching events found
# No baseline correction applied
# 0 projection items activated
# 0 bad epochs dropped
# Not setting metadata
# Not setting metadata
# 15 matching events found
# No baseline correction applied
# 0 projection items activated
# 0 bad epochs dropped
# Not setting metadata
# Not setting metadata
# 15 matching events found
# No baseline correction applied
# 0 projection items activated
# 0 bad epochs dropped
# Not setting metadata
# ...
